# %% [markdown]
# # **Unlock the Secrets of Cartoons Images Generation with Google Tensorflow: GANs in action!**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![2204_w030_n002_376b_p1_376](2204_w030_n002_376b_p1_376.jpg)

# %% [markdown]
# # **Project Background**
#
# - Embark on a captivating journey into the heart of digital creativity, where the vibrant world of cartoons becomes the canvas for our technological masterpiece. Our project, fueled by the advanced capabilities of Google's TensorFlow and the innovative power of Generative Adversarial Networks (GANs), is not just an endeavor in image generation; it's a voyage into the uncharted territories of digital artistry.
#
# - In 2014, Ian J. Goodfellow introduced GANs, revolutionizing the way we perceive image generation. These networks, comprising a duet of generator and discriminator, engage in a fascinating tug-of-war, each striving to outsmart the other. This dynamic interplay lies at the core of our project, transforming complex cartoon characters into a spectrum of pixels that dance to the rhythm of artificial intelligence.
#
# - Our mission transcends the boundaries of technology; it's an ode to the art of complexity, a tribute to the intricate dance of algorithms that paint a thousand colors with a single line of code. By harnessing the robust framework of TensorFlow and the creative pulse of GANs, we are not just generating images; we are weaving a tapestry of digital dreams, each pixel a testament to the possibilities that lie at the intersection of technology and art.
#
# - This endeavor is more than a technical milestone; it's a gateway to a new era of image generation, where the lines between the real and the imagined blur into a canvas of endless possibilities. Our journey is a beacon for image artists worldwide, illuminating a path to new horizons and offering fresh perspectives that challenge the conventional boundaries of creativity.
#
# - Join us on this pioneering quest, where each generated image is a step closer to a future where technology and art converge in a symphony of creativity, crafting a world where the only limit is the imagination. Together, we are not just predicting the nuances of digital art; we are shaping the future of how stories are told and experienced in the kaleidoscopic world of cartoons.

# %% [markdown]
# # Redefining Creativity: The Dawn of a New Era in Cartoon Imagery with Google TensorFlow and the Revolutionary Power of GANs

# %% [markdown]
# **Introduction**:
#
# Welcome to a groundbreaking chapter in our 'Google TensorFlow AI/ML Applications' series on Medium. Dive into the enthralling world of digital creativity, where we pioneer the art of generating complex cartoon characters with unprecedented precision. Leveraging the power of Generative Adversarial Networks (GANs) and fueled by the sophisticated algorithms of TensorFlow, Google's crown jewel in machine learning, we are on the brink of revolutionizing the creative realm for artists.
#
# **The Challenge**:
#
# The task of generating images transcends a mere challenge; it represents an intricate journey through the labyrinthine interactions of generators and discriminators. Armed with the cutting-edge prowess of Artificial Intelligence (AI), spearheaded by Google TensorFlow and GANs, we delve into this labyrinth. TensorFlow stands as a paragon of accuracy and complexity, not only facilitating the intricate dance of digital artistry but also providing a window into the narrative and communicative essence of the cartoon universe.
#
# **Introducing Tensorflow and GANs : The Game-Changer in Machine Learning**:
#
# Join us as we delve into the core of TensorFlow, a brainchild of the ingenious minds at Google Brain. More than a tool, TensorFlow is a groundbreaking stride in machine learning, reshaping our approach to solving complex challenges. From refining wine quality to decoding urban dynamics, it transforms our ability to parse and engage with multifaceted data landscapes. In the world of GANs, where a dynamic duo of generator and discriminator competes in a strategic contest, we witness a riveting game of intellectual chess.
#
# **Join the Journey**:
#
# Our series transcends a mere technological exploration; it is a saga of discovery, unearthing hidden truths within layers of data. We invite you to embark on this magnificent odyssey, as we dissect sophisticated algorithms and weave through the rich tapestry of data. Become an integral part of our exhilarating exploration into TensorFlow & GANs, and witness the metamorphosis of image generation into a realm of digital dreams, where each pixel narrates a story of endless possibilities at the nexus of technology and artistry.

# %% [markdown]
# # Project Approach

# %% [markdown]
# ![Screenshot 2024-02-01 204110](Screenshot%202024-02-01%20204110.png)

# %% [markdown]
# **Revolutionizing Image Generation with TensorFlow & GANs**
#
# Embark on an epic journey into the heart of machine learning with us, as we not just generate cartoon images, but revolutionize the entire domain using the sophisticated prowess of TensorFlow. Our expedition is methodically structured into pivotal phases: defining the vision, mastering the data, and pioneering through innovation.
#
# **Scoping Phase: Envisioning the Future**
#
# Our adventure begins by meticulously crafting the blueprint of our project. In this phase, we set ambitious objectives and identify key elements that will drive our mission. This isn’t just planning; it’s the art of envisioning the future of digital creativity, laying a robust foundation for a journey aimed at unraveling the complexities of image generation.
#
# **Data Collection and Preprocessing: Sculpting the Raw Essence**
#
# Armed with a dataset of 30,000 images, we embark on a deep dive into the core of image generation. This phase is a meticulous journey of cleaning, preprocessing, and feature engineering, transforming raw data into a masterpiece ready for the grand act of creation. Our goal is to refine our dataset to perfection, setting the stage for a modeling process that will capture the essence of digital art.
#
# **Modeling: The Art of AI with TensorFlow and GANs**
#
# At the core of our quest is the development of an advanced model using Keras, empowered by the might of TensorFlow and GANs. This isn’t just modeling; it’s a form of high art where technology meets creativity, crafting predictive masterpieces that capture the subtle nuances of digital storytelling. Here, we don’t just predict; we create and inspire, bringing to life the rich tapestry of cartoon imagery in ways never seen before.
#
# **A New Epoch in Image Generation**
#
# This project transcends a mere series of phases; it heralds a new era in artistic image generation. We are not just achieving technical milestones; we are setting new benchmarks for accuracy and insight, offering a fresh perspective on the intricate world of digital art.
#
# Join us on this exhilarating journey of discovery and innovation, where each step is not just progress but a giant leap toward transforming our understanding and appreciation of digital creativity. With TensorFlow and Generative Adversarial Networks (GANs), we are not just part of the change; we are the change, redefining the landscape of digital artistry.

# %% [markdown]
# # Methodology

# %% [markdown]
# **Unleashing the Transformative Power of TensorFlow and GANs: A Journey Beyond Limits"**
#
# Dive into the realm of AI innovation with us as we unravel the extraordinary capabilities of TensorFlow and Generative Adversarial Networks (GANs). Crafted by the visionaries at Google Brain, TensorFlow emerges not just as a tool but as a symbol of limitless possibilities in the machine learning universe.
#
# At the core of our exploration lies GANs, a captivating dance of creativity and computation where the interplay between generator and discriminator sparks a revolution in digital artistry.
#
# Embracing TensorFlow is more than adopting a framework; it's stepping into a realm of boundless innovation and collaboration. Its open-source ethos invites a global community of developers and researchers to push the boundaries of what's possible, unleashing a wave of transformative advancements that redefine the landscape of AI.
#
# Through our journey with TensorFlow, we navigate through complex data landscapes, sculpting raw information into insightful revelations and groundbreaking discoveries. It's a testament to the fusion of technology and creativity, where each line of code is a brushstroke in a masterpiece of machine intelligence.
#
# Join us as we delve deeper into the heart of TensorFlow and GANs, illuminating the path to a future where AI not only predicts but creates, blurring the lines between imagination and reality in ways previously thought impossible. Together, let's embark on a journey beyond limits, where innovation knows no bounds and the extraordinary becomes the new norm.

# %% [markdown]
# # Process: Charting the Course

# %% [markdown]
# My journey in the Jupyter Notebook was both illuminating and rigorous:
#
# - **Define the Project**: It starts with understanding the business problem.
# - **Data Collection & Dataset creation**: Gathering and grasping the dataset's intricacies.
# - **Data Preprocessing**: The bedrock of the analysis - cleansing and structuring data for machine comprehension.
# - **Model Selection**: Tensorflow & GANs for constructing compelling neural networks
# - **Imges generation**: Generate a real like images of cartoons upon completion of model training

# %%
# !pip install tensorflow

# %% [markdown]
# ## Step 1: Import Libraries and Read Dataset

# %%
import tensorflow as tf
import numpy as np
import sys
import os
import cv2
import glob
from PIL import Image
import matplotlib.pyplot as plt
import time
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import UpSampling2D, Conv2D

# %% [markdown]
# ## Step 2: Dataset Creation

# %%
def load_dataset(batch_size, img_shape, data_dir=None):
    # Create a tuple of size(30000,64,64,3)
    sample_dim = (batch_size,) + img_shape
    # Create an uninitialized array of shape (30000,64,64,3)
    sample = np.empty(sample_dim, dtype=np.float32)
    # Extract all images from our file
    all_data_dirlist = list(glob.glob(data_dir))

    # Randomly select an image file from our data list
    sample_imgs_paths = np.random.choice(all_data_dirlist,batch_size)

    for index,img_filename in enumerate(sample_imgs_paths):
        # Open the image
        image = Image.open(img_filename)
        # Resize the image
        image = image.resize(img_shape[:-1])
        # Convert the input into an array
        image = np.asarray(image)
        # Normalize data
        image = (image/127.5) -1
        # Assign the preprocessed image to our sample
        sample[index,...] = image
    print('data loaded')
    return sample

# %%
x_train=load_dataset(30000,(64,64,3), "/content/drive/MyDrive/Image generation using Tensorflow and GANs/images/*.jpg")
BUFFER_SIZE = 30000
BATCH_SIZE = 256
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Out:
# data loaded

# %% [markdown]
# ## Step 3: Displaying Imgaes

# %% [markdown]
# we can check that the data set is correctly loaded by printing a few images from the set.

# %%
n = 10
f = plt.figure(figsize=(15,15))
for i in range(n):
    f.add_subplot(1, n, i + 1)
    plt.subplot(1, n, i+1 ).axis("off")
    plt.imshow(x_train[i])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# Now check the shape of training data
x_train.shape
# Out:
# (30000, 64, 64, 3)

# %% [markdown]
# From the above, we can see that there are 30000 RGB images each of the size 64x64. At this point we are ready for defining our models, training them, doing inference.

# %% [markdown]
# ## Step 4: Creating a Generator Model

# %%
gen_model = tf.keras.Sequential()

# seed image of size 4x4
gen_model.add(tf.keras.layers.Dense(64*4*4,
                                use_bias=False,
                                input_shape=(100,)))
gen_model.add(tf.keras.layers.BatchNormalization())
gen_model.add(tf.keras.layers.LeakyReLU())

gen_model.add(tf.keras.layers.Reshape((4,4,64)))

# size of output image is still 4x4
gen_model.add(tf.keras.layers.Conv2DTranspose(256, (5, 5),
                                          strides=(1, 1),
                                          padding='same',
                                          use_bias=False))
gen_model.add(tf.keras.layers.BatchNormalization())
gen_model.add(tf.keras.layers.LeakyReLU())

# size of output image is 8x8
gen_model.add(tf.keras.layers.Conv2DTranspose(128, (5, 5),
                                          strides=(2, 2),
                                          padding='same',
                                          use_bias=False))
gen_model.add(tf.keras.layers.BatchNormalization())
gen_model.add(tf.keras.layers.LeakyReLU())

# size of output image is 16x16
gen_model.add(tf.keras.layers.Conv2DTranspose(64, (5, 5),
                                          strides=(2, 2),
                                          padding='same',
                                          use_bias=False))
gen_model.add(tf.keras.layers.BatchNormalization())
gen_model.add(tf.keras.layers.LeakyReLU())

# size of output image is 32x32
gen_model.add(tf.keras.layers.Conv2DTranspose(32, (5, 5),
                                          strides=(2, 2),
                                          padding='same',
                                          use_bias=False))
gen_model.add(tf.keras.layers.BatchNormalization())
gen_model.add(tf.keras.layers.LeakyReLU())

# size of output image is 64x64
gen_model.add(tf.keras.layers.Conv2DTranspose(3, (5, 5),
                                          strides=(2, 2),
                                          padding='same',
                                          use_bias=False,
                                          activation='tanh'))

gen_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1024)              102400
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 1024)              0
#
#  reshape (Reshape)           (None, 4, 4, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 256)         409600
#  anspose)
#
#  batch_normalization_1 (Bat  (None, 4, 4, 256)         1024
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 4, 4, 256)         0
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 128)         819200
#  Transpose)
#
#  batch_normalization_2 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 128)         0
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 64)        204800
#  Transpose)
#
# ...

# %% [markdown]
# ## Step 5: Testing image generator with random input vector

# %%
noise = tf.random.normal([1, 100])
generated_image = gen_model(noise, training=False)
plt.imshow(generated_image[0, :, :, 0] )

# %% [markdown]
# ## Step 6: Defining Discriminator Model

# %%
discri_model = tf.keras.Sequential()
discri_model.add(tf.keras.layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same',input_shape=[64,64,3]))
discri_model.add(tf.keras.layers.LeakyReLU())
discri_model.add(tf.keras.layers.Dropout(0.3))

discri_model.add(tf.keras.layers.Conv2D(256, (5, 5), strides=(2, 2), padding='same'))
discri_model.add(tf.keras.layers.LeakyReLU())
discri_model.add(tf.keras.layers.Dropout(0.3))

discri_model.add(tf.keras.layers.Flatten())
discri_model.add(tf.keras.layers.Dense(1))
discri_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 32, 32, 128)       9728
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  dropout (Dropout)           (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)       819456
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  dropout_1 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# ...
# Total params: 894721 (3.41 MB)
# Trainable params: 894721 (3.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(discri_model)

# %% [markdown]
# ## Step 7: Testing discriminator

# %% [markdown]
# Giving the generated image to discriminator, the discriminator will give negative value if it is fake, while if it is real then it will give positive value.

# %%
decision = discri_model(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.00131371]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ## Step 8: Loss functions

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(generated_output):
    return cross_entropy(tf.ones_like(generated_output),generated_output)

# %%
def discriminator_loss(real_output, generated_output):
    # compute loss considering the image is real [1,1,...,1]
    real_loss = cross_entropy(tf.ones_like(real_output),real_output)

    # compute loss considering the image is fake[0,0,...,0]
    generated_loss = cross_entropy(tf.zeros_like(generated_output),
                                   generated_output)
    # compute total loss
    total_loss = real_loss + generated_loss

    return total_loss

# %% [markdown]
# ## Step 9: Optimizers

# %%
gen_optimizer = tf.optimizers.Adam(1e-4)
discri_optimizer = tf.optimizers.Adam(1e-4)

# %% [markdown]
# ## Step 10: Setting up few variables

# %%
epoch_number = 0
EPOCHS = 10000
noise_dim = 100
seed = tf.random.normal([1, noise_dim])

# %%
checkpoint_dir = '/content/drive/My Drive/GAN3/Checkpoint'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=gen_optimizer,
                                 discriminator_optimizer=discri_optimizer,
                                 generator= gen_model,
                                 discriminator = discri_model)

# %% [markdown]
# ## Step 11: Mounting drive for storing images and checkpoints

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/My Drive/GAN3'
# Out:
# /content/drive/My Drive/GAN3

# %% [markdown]
# ## Step 12: Gradient Tuning Function

# %%
def gradient_tuning(images):
    # create a noise vector.
    noise = tf.random.normal([16, noise_dim])

    # Use gradient tapes for automatic differentiation
    with tf.GradientTape() as generator_tape, tf.GradientTape() as discriminator_tape:

      # ask genertor to generate random images
      generated_images = gen_model(noise, training=True)

      # ask discriminator to evalute the real images and generate its output
      real_output = discri_model(images, training=True)

      # ask discriminator to do the evlaution on generated (fake) images
      fake_output = discri_model(generated_images, training=True)

      # calculate generator loss on fake data
      gen_loss = generator_loss(fake_output)

      # calculate discriminator loss as defined earlier
      disc_loss = discriminator_loss(real_output, fake_output)

    # calculate gradients for generator
    gen_gradients = generator_tape.gradient(gen_loss,
                                               gen_model.trainable_variables)

    # calculate gradients for discriminator
    discri_gradients = discriminator_tape.gradient(disc_loss,
                                        discri_model.trainable_variables)

    # use optimizer to process and apply gradients to variables
    gen_optimizer.apply_gradients(zip(gen_gradients,
                                            gen_model.trainable_variables))

    # same as above to discriminator
    discri_optimizer.apply_gradients(
        zip(discri_gradients,
            discri_model.trainable_variables))

# %% [markdown]
# ## Step 13: Function for generating images at every epoch

# %%
def generate_and_save_images(model, epoch, test_input):
        # use a global count for tracking epochs in case of disconnection
        global epoch_number
        epoch_number = epoch_number + 1

        # set training to false to ensure inference mode
        predictions = model(test_input, training=False)

        # display and save image
        fig = plt.figure(figsize=(4,4))
        for i in range(predictions.shape[0]):
            plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
            plt.axis('off')
        plt.savefig('image_at_epoch_{:01d}.png'.format(epoch_number))
        plt.show()

# %% [markdown]
# ## Step 14:Setting up a training loop

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      gradient_tuning(image_batch)

    # Produce images as we go
    generate_and_save_images(gen_model,
                             epoch + 1,
                             seed)

    # save checkpoint data
    checkpoint.save(file_prefix = checkpoint_prefix)
    print ('Time for epoch {} is {} sec'.format(epoch + 1,
                                                time.time()-start))

# %% [markdown]
# ## Step 15:Model Training

# %%
train(train_dataset, EPOCHS)
# Out:
# Time for epoch 1 is 1111.5075225830078 sec
# Time for epoch 2 is 1102.8022270202637 sec
# Time for epoch 3 is 1079.7106132507324 sec
# Time for epoch 4 is 1100.8479554653168 sec
# Time for epoch 5 is 1079.2403531074524 sec
# Time for epoch 6 is 1102.823170185089 sec
# Time for epoch 7 is 1162.9447343349457 sec
# Time for epoch 8 is 1096.0097498893738 sec
# Time for epoch 9 is 1095.5742647647858 sec
# Time for epoch 10 is 1102.8450117111206 sec
# Time for epoch 11 is 1085.800312757492 sec

# %% [markdown]
# ## Step 16:Conclusion

# %% [markdown]
# - From the above, we can see that by about 1000 epochs , the ntework learns quite a bit to reproduce the original cartoon image.
#
# - To train the model to generate a real like image, we would need to run the code for 10000 epochs or even more.
#
# - Each epoch took me about 20-30 sec on average to run on TPU during first round of training.
#
# - Here this project showed you how the GAN technique using Tesnorflow framework can be applied as is to generate complex lar images of cartoons too.
#
# - Generative Advserserial Network (GAN) provides a novel idea of mimicking any given image. The GAN consists of 2 networks - generator and discriminator. Both models are trained by an advserserial process.
#
# - Today GANs have been successfully used in many applications ex: creation of large image datasets like handwritten digits as well as for generating cartoon characters like anime example mentioned in this project.
#
# - The possibilities are endless. you shoudle xplore further to see for yourself how people have used GANs for creating many interesting applications.
#
# - With the techniques you have learned in this project, you would be able to implement your won ideas to add to this repo of endless GAN applications.
